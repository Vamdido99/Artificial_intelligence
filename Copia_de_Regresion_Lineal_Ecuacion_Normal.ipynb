# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Iniciemos con  la regresión lineal univariada

# %%
x1=np.array([1, 1.5, 2, 2.5, 3, 3.5 , 4, 4.5, 5, 5.5, 6])
x0=np.ones(x1.shape)
y=np.array([0.16,0.28,0.38,0.47,0.60,0.73,0.79,0.87,0.84,0.86,0.96])
X=np.matrix([x0,x1]).T
Y=np.matrix([y]).T
print("shape x0",x0.shape,"shape x1",x1.shape,"shape X",X.shape,"shape Y",Y.shape)
print(X)
print(Y)
# Out:
# shape x0 (11,) shape x1 (11,) shape X (11, 2) shape Y (11, 1)
# [[1.  1. ]
#  [1.  1.5]
#  [1.  2. ]
#  [1.  2.5]
#  [1.  3. ]
#  [1.  3.5]
#  [1.  4. ]
#  [1.  4.5]
#  [1.  5. ]
#  [1.  5.5]
#  [1.  6. ]]
# [[0.16]
#  [0.28]
#  [0.38]
#  [0.47]
#  [0.6 ]
#  [0.73]
#  [0.79]
#  [0.87]
#  [0.84]
#  [0.86]
#  [0.96]]

# %%
from sklearn.metrics import r2_score
Theta=np.linalg.inv(X.T*X)*(X.T)*Y
print(Theta)
plt.plot(x1,y, 'bo')
plt.plot(x1,Theta[0,0]+Theta[1,0]*x1)
plt.title("Final")
plt.show()
R2 = r2_score(y, Theta[0,0]+Theta[1,0]*x1) #coefficient of determination
print("coefficient of determination = ",R2)
# Out:
# [[0.07790909]
#  [0.158     ]]
# coefficient of determination =  0.9385079041558958

# %% [markdown]
# **Ejercicio de vacunados en Colombia**

# %%
#3 Regresiones para total vacunados Colombia
import pandas as pd
df = pd.read_csv("country_vaccinations.csv", sep=';', header=0)
arr = df.values
Xb = arr[:,2:3]
Xa = np.ones((len(Xb),1))
X = np.concatenate((Xa,Xb),axis=1)
Y = arr[:,8] #4
X = np.array(X,dtype='float64') 
Y = np.array(Y,dtype='float64') 
print(Y[1])
# Out:
# 9917.0

# %%
from sklearn.metrics import r2_score
Theta=np.dot(np.linalg.inv(np.dot(X.T,X)),np.dot(X.T,Y)) 
print(Theta)
plt.plot(Xb,Y)
plt.plot(Xb,Theta[0]+Theta[1]*Xb) #Regresión Lineal
plt.title("Regresión Lineal")
plt.xlabel("Días")
plt.ylabel("Total vacunados")
plt.show()

Xx = Theta[0]+Theta[1]*Xb
r2 = r2_score(Y, Theta[0]+Theta[1]*Xb)
print("Coefficient of determination = ",r2)
# Out:
# [100170.02109253    679.77602818]
# Coefficient of determination =  0.3522476654735406

# %%
X = np.concatenate((Xa,Xb,Xb*Xb),axis=1)
Y = arr[:,8]
X = np.array(X,dtype='float64')
Y = np.array(Y,dtype='float64') 
Theta=np.dot(np.linalg.inv(np.dot(X.T,X)),np.dot(X.T,Y)) 
print(Theta)
plt.plot(Xb,Y)
plt.plot(Xb,Theta[0]+Theta[1]*Xb+Theta[2]*Xb*Xb) #Regresión polinomica grado 2
plt.title("Regresión Polinomial grado 2")
plt.xlabel("Días")
plt.ylabel("Total vacunados")
plt.show()

Xx = Theta[0]+Theta[1]*Xb+Theta[2]*Xb*Xb
r2 = r2_score(Y, Theta[0]+Theta[1]*Xb+Theta[2]*Xb*Xb)
print("Coefficient of determination = ",r2)
# Out:
# [-1.75132741e+04  3.01785474e+03 -7.76770337e+00]
# Coefficient of determination =  0.6281997285441909

# %%
X = np.concatenate((Xa,Xb,Xb*Xb,Xb*Xb*Xb),axis=1)
Y = arr[:,8]
X = np.array(X,dtype='float64') 
Y = np.array(Y,dtype='float64') 

Theta=np.dot(np.linalg.inv(np.dot(X.T,X)),np.dot(X.T,Y)) 
print(Theta)
plt.plot(Xb,Y)
plt.plot(Xb,Theta[0]+Theta[1]*Xb+Theta[2]*Xb*Xb+Theta[3]*Xb*Xb*Xb) #Regresión polinomica grado 3
plt.title("Regresión Polinomial grado 3")
plt.xlabel("Días")
plt.ylabel("Total vacunados")
plt.show()

Xx = Theta[0]+Theta[1]*Xb+Theta[2]*Xb*Xb+Theta[3]*Xb*Xb*Xb
r2 = r2_score(Y, Theta[0]+Theta[1]*Xb+Theta[2]*Xb*Xb+Theta[3]*Xb*Xb*Xb)
print("Coefficient of determination = ",r2)
# Out:
# [-4.05875287e+04  3.93017699e+03 -1.53325367e+01  1.67548910e-02]
# Coefficient of determination =  0.6356272710684969

# %% [markdown]
# # Regresion Multivariada de ejemplo

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Datos_multivariados.csv", sep=';',header=0)#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
arr=df.values
YCOL=3
Xb=arr[:,0:YCOL]
Xa=np.ones((len(Xb),1))
X=np.concatenate((Xa,Xb),axis=1)
Y=arr[:,YCOL]
Theta=np.dot(np.linalg.inv(np.dot(X.T,X)),np.dot(X.T,Y))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-c1a0abb1e7e6> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df=pd.read_csv("Datos_multivariados.csv", sep=';',header=0)#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#       4 arr=df.values
#       5 YCOL=3
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
print(Theta)
# Out:
# [-1.00000000e+04  2.00000011e+00  1.50000000e-01 -4.99999792e+00]
